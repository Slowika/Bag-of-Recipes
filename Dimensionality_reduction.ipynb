# %% [markdown]
# # Dimensionality reduction with PCA

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sklearn
import seaborn as sns
from similarity_functions import asymmetric_cosine, jaccard 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# Load data.
X_train = pd.read_csv('train_dataset.csv', sep = '\t', index_col = 0).drop('cuisine', axis = 1)
cuisines = pd.read_csv('train_dataset.csv', sep = '\t', usecols = ['cuisine'])
cuisines.set_index(X_train.index, inplace = True)

# %%
# Transpose matrix
X_T = X_train.T

# Number of rows
n = X_T.shape[1]
print("number of recipes:", n)

X_T.head()
# Out:
# number of recipes: 37642
#                   10259  25693  20130  13162  6602   42779  3735   16903  \
# active_dry_yeast      0      0      0      0      0      0      0      0
# allpurpose_flour      0      0      0      0      0      0      0      0
# asparagus             0      0      0      0      0      0      0      0
# avocado               0      0      0      0      0      0      0      0
# bacon                 0      0      0      0      0      0      0      0
#
#                   12734  5875   ...    8089   6153   25557  24348  7377   \
# active_dry_yeast      0      0  ...        0      0      0      0      0
# allpurpose_flour      0      0  ...        0      0      0      0      0
# asparagus             0      0  ...        0      0      0      0      0
# avocado               0      0  ...        0      0      0      0      0
# bacon                 0      0  ...        0      0      1      0      0
#
#                   29109  11462  2238   41882  2362
# active_dry_yeast      0      0      0      0      0
# allpurpose_flour      1      0      0      0      0
# asparagus             0      0      0      0      0
# avocado               0      0      0      0      0
# bacon                 0      0      0      0      0
#
# [5 rows x 37642 columns]

# %%
# PCA object
pca = PCA(n_components = n)

# Fit and transform to obtain the transpose of the desired PCA matrix
X_train_pca_T = pca.fit_transform(X_T)

# Transpose result
X_train_pca = X_train_pca_T.T

# %%
X_train_pca = pd.DataFrame(X_train_pca)
X_train_pca.columns = X_train.columns
X_train_pca.head()
# Out:
#    active_dry_yeast  allpurpose_flour  asparagus   avocado     bacon  \
# 0         -3.685896         13.531451  -4.001805  0.664546  0.327978
# 1          2.034662         37.256966  -0.974573 -3.913528 -0.198961
# 2         -0.837259        -13.040835  -0.416496  0.021378 -0.313758
# 3         -1.258111        -14.658438  -0.488222  1.268475 -2.748163
# 4         -0.059772          7.024982  -0.164973 -2.188809  2.152510
#
#    baguette  baking_soda   bananas     basil     beans         ...          \
# 0 -3.703016    -2.618809 -4.500371 -2.662131  2.944753         ...
# 1 -1.041645     9.696116  0.415130 -0.853306 -3.854108         ...
# 2 -0.908353    -1.593355  0.081946  0.712751 -0.124640         ...
# 3 -0.137379    -2.866941 -0.876419  0.564812 -0.594265         ...
# 4 -0.184827     0.729459  0.222970 -0.873841  1.464920         ...
#
#    mushrooms_sliced  vegetable  potatoes_sweet  vegetable_cooking_spray  \
# 0         -3.721170  15.783032       -3.013392                -4.116599
# 1         -1.033850  11.893141        0.078598                -0.594709
# 2         -0.170030  14.020404       -0.060067                -0.416783
# 3         -1.068749  18.193690       -0.929170                -0.845110
# 4          0.119635   9.833243        0.594255                 0.212739
#
#    vinegar_white  onion_white  pepper_white  vinegar_white_wine  \
# 0      -2.442006    -2.078884     -3.331249           -3.382111
# 1       0.197027    -1.644614      0.271156           -1.097191
# 2       1.018363    -0.255899      1.712380           -0.816706
# 3       0.589853     1.020370      0.414076           -0.074249
# 4      -0.279539    -1.049763     -0.804990           -0.394225
#
#    flour_wheat_whole  pepper_yellow_bell
# 0          -4.349536           -3.251487
# 1           0.172475           -1.538786
# 2          -0.160642           -0.785660
# 3          -1.100721           -0.148001
# 4           0.338724           -0.247137
#
# [5 rows x 306 columns]

# %%
X_train_pca.to_csv('train_dataset_recipepca.csv', sep = '\t')
