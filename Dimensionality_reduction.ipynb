# %% [markdown]
# # Dimensionality reduction with PCA

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sklearn
import seaborn as sns
from similarity_functions import asymmetric_cosine, jaccard 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# Load data.
X_train = pd.read_csv('train_dataset.csv', sep = '\t', index_col = 0).drop('cuisine', axis = 1)
cuisines = pd.read_csv('train_dataset.csv', sep = '\t', usecols = ['cuisine'])
cuisines.set_index(X_train.index, inplace = True)

# %%
X_train.head()
# Out:
#        active_dry_yeast  allpurpose_flour  avocado  bacon  baguette  \
# 10259                 0                 0        0      0         0
# 25693                 0                 0        0      0         0
# 20130                 0                 0        0      0         0
# 13162                 0                 0        0      0         0
# 6602                  0                 0        0      0         0
#
#        baking_soda  basil  beans  beansprouts  beef         ...          \
# 10259            0      0      1            0     0         ...
# 25693            0      0      0            0     0         ...
# 20130            0      0      0            0     0         ...
# 13162            0      0      0            0     0         ...
# 6602             0      0      0            0     0         ...
#
#        mozzarella_shredded_cheese  onions_sliced_green  vegetable  \
# 10259                           0                    0          0
# 25693                           0                    0          1
# 20130                           0                    0          0
# 13162                           0                    0          0
# 6602                            0                    0          0
#
#        potatoes_sweet  vegetable_cooking_spray  vinegar_white  onion_white  \
# 10259               0                        0              0            0
# 25693               0                        0              0            0
# 20130               0                        0              0            0
# 13162               0                        0              0            0
# 6602                0                        0              0            0
#
#        pepper_white  vinegar_white_wine  pepper_yellow_bell
# 10259             0                   0                   0
# 25693             0                   0                   0
# 20130             0                   0                   0
# 13162             0                   0                   0
# 6602              0                   0                   0
#
# [5 rows x 267 columns]

# %%
# Transpose matrix
X_T = X_train.T

# Number of rows
n = X_T.shape[1]
print("number of recipes:", n)

X_T.head()
# Out:
# number of recipes: 37340
#                   10259  25693  20130  13162  6602   42779  3735   16903  \
# active_dry_yeast      0      0      0      0      0      0      0      0
# allpurpose_flour      0      0      0      0      0      0      0      0
# avocado               0      0      0      0      0      0      0      0
# bacon                 0      0      0      0      0      0      0      0
# baguette              0      0      0      0      0      0      0      0
#
#                   12734  5875   ...    8089   6153   25557  24348  7377   \
# active_dry_yeast      0      0  ...        0      0      0      0      0
# allpurpose_flour      0      0  ...        0      0      0      0      0
# avocado               0      0  ...        0      0      0      0      0
# bacon                 0      0  ...        0      0      1      0      0
# baguette              0      0  ...        0      0      0      0      0
#
#                   29109  11462  2238   41882  2362
# active_dry_yeast      0      0      0      0      0
# allpurpose_flour      1      0      0      0      0
# avocado               0      0      0      0      0
# bacon                 0      0      0      0      0
# baguette              0      0      0      0      0
#
# [5 rows x 37340 columns]

# %%
# PCA object
pca = PCA(n_components = n)

# Fit and transform to obtain the transpose of the desired PCA matrix
X_train_pca_T = pca.fit_transform(X_T)

# Transpose result
X_train_pca = X_train_pca_T.T

# %%
X_train_pca = pd.DataFrame(X_train_pca)
X_train_pca.columns = X_train.columns
X_train_pca.head()
# Out:
#    active_dry_yeast  allpurpose_flour   avocado     bacon  baguette  \
# 0         -4.226202         12.320884 -0.005376 -0.222035 -4.211263
# 1          1.879610         37.647692 -4.083548 -0.268213 -1.204777
# 2         -0.836278        -13.026019  0.004456 -0.323731 -0.902204
# 3         -1.355229        -14.003337  0.850557 -2.797684 -0.270012
# 4         -0.002948          6.994738 -2.078868  2.258141 -0.139643
#
#    baking_soda     basil     beans  beansprouts      beef         ...          \
# 0    -3.344270 -3.221364  2.385825    -3.703250 -1.196846         ...
# 1     9.577921 -1.012628 -3.933304     0.008900 -0.531252         ...
# 2    -1.574164  0.730311 -0.150121     2.466200  2.194721         ...
# 3    -2.855993  0.417839 -0.772119     2.246197  0.345336         ...
# 4     0.757194 -0.831923  1.576642    -0.802017  1.329311         ...
#
#    mozzarella_shredded_cheese  onions_sliced_green  vegetable  potatoes_sweet  \
# 0                   -3.489603            -3.857968  14.617534       -3.555858
# 1                   -1.425662            -0.933354  11.970045       -0.059157
# 2                   -0.884236            -0.439898  14.071268       -0.061459
# 3                   -2.740197             0.481975  18.431779       -1.040781
# 4                   -0.172760             0.053787   9.387959        0.657032
#
#    vegetable_cooking_spray  vinegar_white  onion_white  pepper_white  \
# 0                -4.629896      -3.005936    -2.662959     -3.900870
# 1                -0.764868       0.038476    -1.807476      0.106766
# 2                -0.432660       1.028404    -0.251001      1.730022
# 3                -0.999895       0.465059     0.811773      0.277232
# 4                 0.283215      -0.246152    -1.013676     -0.764933
#
#    vinegar_white_wine  pepper_yellow_bell
# 0           -3.902531           -3.765000
# 1           -1.259017           -1.698306
# 2           -0.808038           -0.779638
# 3           -0.209404           -0.291876
# 4           -0.351068           -0.194087
#
# [5 rows x 267 columns]

# %%
X_train_pca.shape
# Out:
# (267, 267)

# %%
X_train_pca.to_csv('train_dataset_recipe_pca.csv', sep = '\t')
